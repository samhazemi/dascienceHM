# %%
import tweepy
import json
import pandas as pd
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
consumer_key = 'e1s1DYp74uStIW5L7mvytx5Z7'
consumer_secret = '9R5ZyqjIrlIoEyJM1UOfUjANuHI6g7emju8KC1GF3tZf3e2tR6'
access_token = '47794770-8AsFjEEKXveZAa2QFIpCllIzVq8f9JwERU9yEyFI6'
access_token_secret = 'YUAmKAxlmKLUV3GH9UNpXax01QDqmGIJmbiQQlHho3V45'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
sentiments = []

target_users = ("@BBC", "@CBS", "@CNN", "@FoxNews", "@NYTimes")


for user in target_users:
    
    

    counter = 0
    
    

    
    public_tweets = api.user_timeline(user, count = 100)

        
    for tweet in public_tweets:

        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        tweet_text = tweet["text"]

        
        sentiments.append({"User" : user,
                           "Date": tweet["created_at"],
                           "Compound" : compound,
                           "Positive" : pos,
                           "Negative" : neg,
                           "Neutral" : neu,
                           "Tweets Ago" : counter,
                           "Tweet Text" : tweet_text})
        

        counter = counter + 1

# %%
news_sentiments = pd.DataFrame.from_dict(sentiments)
news_sentiments
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0      0.8625  Sat Mar 17 14:00:30 +0000 2018     0.000    0.699     0.301
# 1      0.3628  Sat Mar 17 13:46:15 +0000 2018     0.073    0.784     0.143
# 2      0.4019  Sat Mar 17 13:00:08 +0000 2018     0.000    0.881     0.119
# 3     -0.7244  Sat Mar 17 12:39:41 +0000 2018     0.336    0.664     0.000
# 4      0.5106  Sat Mar 17 12:00:09 +0000 2018     0.112    0.643     0.245
# 5      0.8883  Sat Mar 17 11:30:09 +0000 2018     0.000    0.488     0.512
# 6      0.6249  Sat Mar 17 11:03:05 +0000 2018     0.000    0.796     0.204
# 7      0.6996  Sat Mar 17 10:14:25 +0000 2018     0.066    0.658     0.276
# 8      0.0000  Sat Mar 17 10:00:02 +0000 2018     0.000    1.000     0.000
# 9     -0.7717  Sat Mar 17 09:39:19 +0000 2018     0.251    0.749     0.000
# 10     0.6369  Sat Mar 17 09:00:06 +0000 2018     0.000    0.714     0.286
# 11     0.7783  Fri Mar 16 19:38:34 +0000 2018     0.000    0.726     0.274
# 12     0.4926  Fri Mar 16 18:31:01 +0000 2018     0.000    0.610     0.390
# 13     0.5719  Fri Mar 16 17:00:25 +0000 2018     0.000    0.791     0.209
# 14     0.0000  Fri Mar 16 16:30:01 +0000 2018     0.000    1.000     0.000
# 15     0.0000  Fri Mar 16 16:00:00 +0000 2018     0.000    1.000     0.000
# 16     0.0000  Fri Mar 16 14:25:15 +0000 2018     0.000    1.000     0.000
# 17     0.3400  Fri Mar 16 14:00:13 +0000 2018     0.000    0.841     0.159
# 18     0.6124  Fri Mar 16 12:59:01 +0000 2018     0.000    0.667     0.333
# 494    0.0000  Fri Mar 16 15:35:04 +0000 2018     0.000    1.000     0.000
# 495   -0.3818  Fri Mar 16 15:25:07 +0000 2018     0.110    0.890     0.000
# 496    0.4767  Fri Mar 16 15:15:09 +0000 2018     0.000    0.819     0.181
# 497    0.0000  Fri Mar 16 15:05:00 +0000 2018     0.000    1.000     0.000
# 498   -0.6597  Fri Mar 16 14:55:07 +0000 2018     0.256    0.659     0.085
# 499   -0.3612  Fri Mar 16 14:45:00 +0000 2018     0.111    0.889     0.000
#
#                                             Tweet Text  Tweets Ago      User
# 0    ⛷❤️ George has autism and other health conditi...           0      @BBC
# 1    RT @5liveSport: 'My mates didn't know I was pl...           1      @BBC
# 2    Yes, Gary Oldman and @BBCEastEnders' Big Mo ar...           2      @BBC
# 3    RT @BBCOne: .@NiallOfficial won't let fame get...           3      @BBC
# 4    ♻️🗑 This shop encourages you to bring your own...           4      @BBC
# 5    🇮🇪 🍀 Celebrate #StPatricksDay in true Irish st...           5      @BBC
# 6    From scrambled eggs to chilli-spiced crisps: h...           6      @BBC
# 7    RT @BBCTwo: Happy #StPatricksDay! Check out wh...           7      @BBC
# 8    🎶🐦 Did you know that bullfinches can learn to ...           8      @BBC
# 9    RT @BBCEngland: Stephen Hawking's PhD thesis h...           9      @BBC
# 10   Ready to get active?\n🏃 Here are 5 ways you ca...          10      @BBC
# 11   RT @BBCR1: This guy just raised over a million...          11      @BBC
# 12   💪😲⚽️ Keepy-uppy the good work! https://t.co/lF...          12      @BBC
# 13   ❤️🎧 Bradley has never let Asperger's hold him ...          13      @BBC
# 14   Running for the door on a Friday afternoon lik...          14      @BBC
# 15   🔊🎵Jarvis Cocker describes the dream-like exper...          15      @BBC
# 16   RT @BBCR1: The gruelling task of climbing Ben ...          16      @BBC
# 17   Prepare to get that warm fuzzy feeling - the m...          17      @BBC
# 18   🤔🎨 Why are soap bubbles such gorgeous colours?...          18      @BBC
# 19   RT @BBCNewsPR: Get ready to make the headlines...          19      @BBC
# 20   😂 Fights, funerals, and giant furry heads... @...          20      @BBC
# 21   RT @BBCRadio2: It's with a heavy heart that to...          21      @BBC
# 22   Are you getting enough sleep? This simple test...          22      @BBC
# 23   RT @bbcthree: the dancing in taylor swift's ne...          23      @BBC
# 24   RT @BBCEngland: Oscar-winning British short fi...          24      @BBC
# 25   RT @BBCScotlandNews: Meet Chloe - the five-yea...          25      @BBC
# 26   RT @BBCWales: 🌼 Daffodils dance in the spring ...          26      @BBC
# 27   💪 After having his leg amputated, @MarkSmithBB...          27      @BBC
# 28   🌸🌻🌺\nTake a look at some of the strangest, sca...          28      @BBC
# 29   😬🛰🌏 Brace yourselves... a Chinese space statio...          29      @BBC
# ..                                                 ...         ...       ...
# 470  Despite a celebrated refugee settlement system...          70  @NYTimes
# 471  “She was an angel. She wanted to become a lawy...          71  @NYTimes
# 472  All “doors-off” helicopter flights have been h...          72  @NYTimes
# 473  Nearly 3 in 4 teachers oppose letting staff ca...          73  @NYTimes
# 474  “Stealing an instrument in New Orleans is like...          74  @NYTimes
# 475  One NYT reader's reaction to South Africa's fo...          75  @NYTimes
# 476  After Trump fired Rex Tillerson in a tweet, we...          76  @NYTimes
# 477  The price French bulldogs pay for being so cut...          77  @NYTimes
# 478  NASA had to set the record straight: Mark Kell...          78  @NYTimes
# 479  Where President Trump goes wrong on trade, and...          79  @NYTimes
# 480  Ben Carson and David Shulkin remain in their c...          80  @NYTimes
# 481  Modern Love: He was struggling with an obscure...          81  @NYTimes
# 482  When Sheryl Sandberg’s book published 5 years ...          82  @NYTimes
# 483  In @NYTOpinion \n\nWuilly Arteaga, an exiled v...          83  @NYTimes
# 484  When Sheryl Sandberg’s book published 5 years ...          84  @NYTimes
# 485  It’s a bold plan to wean Californians from the...          85  @NYTimes
# 486  In @NYTOpinion \n\nOp-Ed Columnist @DouthatNYT...          86  @NYTimes
# 487  Readers wrote in with their accounts of workpl...          87  @NYTimes
# 488  The Bollywood legend, Madhubala has been compa...          88  @NYTimes
# 489  A study confirms what news reports have sugges...          89  @NYTimes
# 490  Is your NCAA bracket still intact? Here's what...          90  @NYTimes
# 491  We visit the Kafkaesque Office of Administrati...          91  @NYTimes
# 492  Our recap of the latest episode of "Atlanta" h...          92  @NYTimes
# 493  How to learn about Quebec's identity? Have a m...          93  @NYTimes
# 494  Trump's new chief economic adviser is known fo...          94  @NYTimes
# 495  RT @NYTSports: Catch up on last night's NCAA t...          95  @NYTimes
# 496  The prompt: “Draw an effective leader.” Both m...          96  @NYTimes
# 497  Since 1851, obituaries in The New York Times h...          97  @NYTimes
# 498  Snapchat shares fell 4% after Rihanna criticiz...          98  @NYTimes
# 499  “Somebody must show that the Afro-American rac...          99  @NYTimes
#
# [500 rows x 8 columns]

# %%
news_sentiments.to_csv("Twitter_News_Mood.csv", index=False)

# %%
plt.xlim(101, -1)


for user in target_users:
    dataframe = news_sentiments.loc[news_sentiments["User"] == user]
    plt.scatter(dataframe["Tweets Ago"],dataframe["Compound"],label = user)
    

plt.legend(bbox_to_anchor = (1,1))


plt.title("Sentiment Analysis of Media Tweets (11/5/2017)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")


plt.grid()

plt.savefig("Sentiment Analysis of Media Tweets")
plt.show()

# %%
average_sentiment = news_sentiments.groupby("User")["Compound"].mean()
average_sentiment
# Out:
# User
# @BBC        0.173452
# @CBS        0.314302
# @CNN       -0.100609
# @FoxNews   -0.208632
# @NYTimes   -0.072255
# Name: Compound, dtype: float64

# %%
x_axis = np.arange(len(average_sentiment))
xlabels = average_sentiment.index
count = 0
for sentiment in average_sentiment:
    plt.text(count, sentiment+.01, str(round(sentiment,2)))
    count = count + 1
plt.bar(x_axis, average_sentiment, tick_label = xlabels, color = ['silver', 'b', 'y', 'g', 'c'])
#Set title, x axis label, and y axis label.
plt.title("Overall Sentiment of Media Tweets (11/5/2017)")
plt.xlabel("New Organizations")
plt.ylabel("Tweet Polarity")
plt.savefig("Overall Sentiment of Media Tweets")
plt.show()
